# %% [markdown]
# # Introducción a Redis
#
# Estos son ejercicios de conexión a Redis

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
# !ls / -la
# Out:
# total 64
# drwxr-xr-x   1 root root 4096 Oct 21 08:25 .
# drwxr-xr-x   1 root root 4096 Oct 21 08:25 ..
# lrwxrwxrwx   1 root root    7 Oct  4  2023 bin -> usr/bin
# drwxr-xr-x   2 root root 4096 Apr 18  2022 boot
# drwxr-xr-x   5 root root  340 Oct 29 07:48 dev
# -rwxr-xr-x   1 root root    0 Oct 21 08:25 .dockerenv
# drwxr-xr-x   1 root root 4096 Oct 21 08:25 etc
# drwxr-xr-x   1 root root 4096 Oct 20  2023 home
# lrwxrwxrwx   1 root root    7 Oct  4  2023 lib -> usr/lib
# lrwxrwxrwx   1 root root    9 Oct  4  2023 lib32 -> usr/lib32
# lrwxrwxrwx   1 root root    9 Oct  4  2023 lib64 -> usr/lib64
# lrwxrwxrwx   1 root root   10 Oct  4  2023 libx32 -> usr/libx32
# drwxr-xr-x   2 root root 4096 Oct  4  2023 media
# drwxr-xr-x   2 root root 4096 Oct  4  2023 mnt
# drwxr-xr-x   1 root root 4096 Oct 20  2023 opt
# dr-xr-xr-x 284 root root    0 Oct 29 07:48 proc
# drwx------   2 root root 4096 Oct  4  2023 root
# drwxr-xr-x   5 root root 4096 Oct  4  2023 run
# ...

# %%
# !pip install redis

# %%
import redis

r = redis.Redis(
    host='redis',
    port=6379,
    db=0,
    decode_responses=True
)

# %%
r.ping()
# Out:
# True

# %%
r.set("ciclo", "Especializacion IA y Big Data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 r.set("ciclo", "Especializacion IA y Big Data")
#
# NameError: name 'r' is not defined

# %%
print(r.get("ciclo"))
# Out:
# Especializacion IA y Big Data

# %%
r.set("curso", "primero", ex=10)
# Out:
# True

# %%
r.set("contador", 300, nx=True)

# %%
print(r.get("contador"))
# Out:
# 100

# %%
print(r.keys("c*"))
# Out:
# ['contador', 'ciclo']

# %%
r.rpush(lista_nombre, "Estudiar Python")
